# %%
import joblib
X_train = joblib.load("../data/processed/X_train.pkl")
X_test = joblib.load("../data/processed/X_test.pkl")
y_train = joblib.load("../data/processed/y_train.pkl")
y_test = joblib.load("../data/processed/y_test.pkl")


import pandas as pd
import numpy as np
df = pd.read_csv("../data/cleaned/cleaned_dataset.csv")

# Drop obvious non-feature columns manually
X = df.drop("pha", axis=1)

# If needed, drop non-numeric columns
X = X.select_dtypes(include=[np.number])

y = df["pha"]

print("Number of features:", X.shape[1])
# Out:
# Number of features: 23

# %%
print("Current cleaned columns:")
print(df.drop("pha", axis=1).columns.tolist())

print("\nFeatures used in model (shape):", X_train.shape[1])
# Out:
# Current cleaned columns:
# ['neo', 'H', 'diameter', 'albedo', 'e', 'a', 'q', 'i', 'om', 'w', 'ma', 'ad', 'n', 'tp', 'tp_cal', 'per', 'per_y', 'moid', 'moid_ld', 'class', 'rms', 'epoch_year', 'epoch_month', 'epoch_day']
#
# Features used in model (shape): 35

# %%
X_train.shape
# Out:
# (766819, 35)

# %%
df.shape
# Out:
# (958524, 25)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 958524 entries, 0 to 958523
# Data columns (total 25 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   neo          958524 non-null  int64
#  1   pha          958524 non-null  float64
#  2   H            958524 non-null  float64
#  3   diameter     958524 non-null  float64
#  4   albedo       958524 non-null  float64
#  5   e            958524 non-null  float64
#  6   a            958524 non-null  float64
#  7   q            958524 non-null  float64
#  8   i            958524 non-null  float64
#  9   om           958524 non-null  float64
#  10  w            958524 non-null  float64
#  11  ma           958524 non-null  float64
#  12  ad           958524 non-null  float64
#  13  n            958524 non-null  float64
#  14  tp           958524 non-null  float64
#  15  tp_cal       958524 non-null  float64
#  16  per          958524 non-null  float64
#  17  per_y        958524 non-null  float64
# ...
